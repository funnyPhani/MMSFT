# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data for "Avg." values
data_monolingual = [
    [26.98, 10.60, 21.56],
    [27.31, 11.40, 22.00],
    [28.11, 12.16, 23.25]
]

data_multilingual = [
    [29.55, 13.34, 24.69],
    [29.92, 14.87, 24.56],
    [31.67, 15.29, 26.17]
]

# Labels
metrics = ['ROUGE-1', 'ROUGE-2', 'ROUGE-L']
scenarios = ['mT5', 'VG-mT5', 'MMSFT']
hatch_patterns = ['//', '++', 'xx']

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Set a smaller width for the bars
width = 0.2

# Calculate positions for side-by-side bars
x = np.arange(len(metrics))
x_monolingual = x - width
x_multilingual = x

# Create bar plots for monolingual scenario
for i, scenario in enumerate(scenarios):
    bars = axs[0].bar(x_monolingual + i * width, data_monolingual[i], width, label=f'{scenario}', hatch=hatch_patterns[i])
    
    # Add numbering on top of bars
    for bar in bars:
        height = bar.get_height()
        axs[0].annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', size=8, fontweight='bold')

# Set the x-axis labels and title for the first subplot
axs[0].set_xticks(x)
axs[0].set_xticklabels(metrics, fontweight='bold', ha='center')
axs[0].set_xlabel('Metrics',fontweight='bold', ha='center')
axs[0].set_ylabel('Average ROUGE Score',fontweight='bold', ha='center')
axs[0].set_title('Monolingual Training Scenario',fontweight='bold', ha='center')
axs[0].legend()

# Create bar plots for multilingual scenario
for i, scenario in enumerate(scenarios):
    bars = axs[1].bar(x_multilingual + i * width, data_multilingual[i], width, label=f'{scenario}', hatch=hatch_patterns[i])
    
    # Add numbering on top of bars
    for bar in bars:
        height = bar.get_height()
        axs[1].annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', size=8, fontweight='bold')

# Set the x-axis labels and title for the second subplot
axs[1].set_xticks(x)
axs[1].set_xticklabels(metrics, fontweight='bold', ha='center')
# axs[1].set_xlabel('Metrics',fontweight='bold', ha='center')
# axs[1].set_ylabel('Average ROUGE Score',fontweight='bold', ha='center')
axs[1].set_title('Multilingual Training Scenario',fontweight='bold', ha='center')
axs[1].legend()

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data for "Avg." values
data_monolingual = [
    [26.98, 10.60, 21.56],
    [27.31, 11.40, 22.00],
    [28.11, 12.16, 23.25]
]

data_multilingual = [
    [29.55, 13.34, 24.69],
    [29.92, 14.87, 24.56],
    [31.67, 15.29, 26.17]
]

# Labels
metrics = ['ROUGE-1', 'ROUGE-2', 'ROUGE-L']
scenarios = ['mT5', 'VG-mT5', 'MMSFT']
hatch_patterns = ['//', '++', 'xx']

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Set a smaller width for the bars
width = 0.2

# Calculate positions for side-by-side bars
x = np.arange(len(metrics))
x_monolingual = x - width
x_multilingual = x + width  # Adjusted for spacing

# Create bar plots for monolingual scenario
for i, scenario in enumerate(scenarios):
    bars = axs[0].bar(x_monolingual + i * width, data_monolingual[i], width, label=f'{scenario}', hatch=hatch_patterns[i])
    
    # Add numbering on top of bars
    for bar in bars:
        height = bar.get_height()
        axs[0].annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', size=8, fontweight='bold')

# Set the x-axis labels and title for the first subplot
axs[0].set_xticks(x)
axs[0].set_xticklabels(metrics, fontweight='bold', ha='center')
axs[0].set_ylabel('Average ROUGE Score', fontweight='bold', ha='center')
axs[0].set_title('Monolingual Training Scenario', fontweight='bold', ha='center')
axs[0].legend()

# Create bar plots for multilingual scenario
for i, scenario in enumerate(scenarios):
    bars = axs[1].bar(x_multilingual + i * width, data_multilingual[i], width, label=f'{scenario}', hatch=hatch_patterns[i])
    
    # Add numbering on top of bars
    for bar in bars:
        height = bar.get_height()
        axs[1].annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', size=8, fontweight='bold')

# Set the x-axis labels and title for the second subplot
axs[1].set_xticks(x)
axs[1].set_xticklabels(metrics, fontweight='bold', ha='center')
axs[1].set_title('Multilingual Training Scenario', fontweight='bold', ha='center')
axs[1].legend()

# Set a common x-axis label for both subplots
fig.text(0.5, -0.1, 'Low-Resources ROUGE Scores', ha='center', fontweight='bold')

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data for "Avg." values
data_monolingual = [
    [26.98, 10.60, 21.56],
    [27.31, 11.40, 22.00],
    [28.11, 12.16, 23.25]
]

data_multilingual = [
    [29.55, 13.34, 24.69],
    [29.92, 14.87, 24.56],
    [31.67, 15.29, 26.17]
]

# Labels
metrics = ['ROUGE-1', 'ROUGE-2', 'ROUGE-L']
scenarios = ['mT5', 'VG-mT5', 'MMSFT']
hatch_patterns = ['//', '++', 'xx']

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Set a smaller width for the bars
width = 0.2

# Calculate positions for side-by-side bars
x = np.arange(len(metrics))
x_monolingual = x - width
x_multilingual = x + width  # Adjusted for spacing

# Create bar plots for monolingual scenario
for i, scenario in enumerate(scenarios):
    bars = axs[0].bar(x_monolingual + i * width, data_monolingual[i], width, label=f'{scenario}', hatch=hatch_patterns[i])
    
    # Add numbering on top of bars
    for bar in bars:
        height = bar.get_height()
        axs[0].annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', size=8, fontweight='bold')

# Set the x-axis labels and title for the first subplot
axs[0].set_xticks(x)
axs[0].set_xticklabels(metrics, fontweight='bold', ha='center')
axs[0].set_ylabel('Average ROUGE Score', fontweight='bold', ha='center')
axs[0].set_title('Monolingual Training Scenario', fontweight='bold', ha='center')
axs[0].legend()

# Calculate midpoints for x-axis tick labels in the multilingual scenario
x_tick_midpoints_multilingual = x_multilingual + (len(scenarios) - 1) * width / 2

# Create bar plots for multilingual scenario
for i, scenario in enumerate(scenarios):
    bars = axs[1].bar(x_multilingual + i * width, data_multilingual[i], width, label=f'{scenario}', hatch=hatch_patterns[i])
    
    # Add numbering on top of bars
    for bar in bars:
        height = bar.get_height()
        axs[1].annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', size=8, fontweight='bold')

# Set the x-axis labels and title for the second subplot
axs[1].set_xticks(x_tick_midpoints_multilingual)  # Use calculated midpoints for tick labels
axs[1].set_xticklabels(metrics, fontweight='bold', ha='center')
axs[1].set_title('Multilingual Training Scenario', fontweight='bold', ha='center')
axs[1].legend()

# Set a common x-axis label for both subplots
# fig.text(0.5, -0.0005, 'Low-Resources ROUGE Scores', ha='center', fontweight='bold')

# Adjust layout
plt.tight_layout()
plt.savefig('low_rouge_scores_plot.png', dpi=700)
# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data for "Avg." values
data_monolingual = [
    [33.62, 13.41, 27.77],
    [34.34, 13.57, 28.75],
    [34.42, 14.02, 29.17]
]

data_multilingual = [
    [35.54, 14.14, 27.22],
    [35.26, 14.46, 28.81],
    [37.84, 16.33, 31.36]
]

# Labels
metrics = ['ROUGE-1', 'ROUGE-2', 'ROUGE-L']
scenarios = ['mT5', 'VG-mT5', 'MMSFT']
hatch_patterns = ['//', '++', 'xx']

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

# Set a smaller width for the bars
width = 0.2

# Calculate positions for side-by-side bars
x = np.arange(len(metrics))
x_monolingual = x - width
x_multilingual = x + width  # Adjusted for spacing

# Create bar plots for monolingual scenario
for i, scenario in enumerate(scenarios):
    bars = axs[0].bar(x_monolingual + i * width, data_monolingual[i], width, label=f'{scenario}', hatch=hatch_patterns[i])
    
    # Add numbering on top of bars
    for bar in bars:
        height = bar.get_height()
        axs[0].annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', size=8, fontweight='bold')

# Set the x-axis labels and title for the first subplot
axs[0].set_xticks(x)
axs[0].set_xticklabels(metrics, fontweight='bold', ha='center')
axs[0].set_ylabel('Average ROUGE Score', fontweight='bold', ha='center')
axs[0].set_title('Monolingual Training Scenario', fontweight='bold', ha='center')
axs[0].legend()

# Calculate midpoints for x-axis tick labels in the multilingual scenario
x_tick_midpoints_multilingual = x_multilingual + (len(scenarios) - 1) * width / 2

# Create bar plots for multilingual scenario
for i, scenario in enumerate(scenarios):
    bars = axs[1].bar(x_multilingual + i * width, data_multilingual[i], width, label=f'{scenario}', hatch=hatch_patterns[i])
    
    # Add numbering on top of bars
    for bar in bars:
        height = bar.get_height()
        axs[1].annotate(f'{height:.2f}', xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3), textcoords='offset points', ha='center', size=8, fontweight='bold')

# Set the x-axis labels and title for the second subplot
axs[1].set_xticks(x_tick_midpoints_multilingual)  # Use calculated midpoints for tick labels
axs[1].set_xticklabels(metrics, fontweight='bold', ha='center')
axs[1].set_title('Multilingual Training Scenario', fontweight='bold', ha='center')
axs[1].legend()

# Set a common x-axis label for both subplots
# fig.text(0.5, -0.0005, 'Mid-High-Resources ROUGE Scores', ha='center', fontweight='bold')

# Adjust layout
plt.tight_layout()
plt.savefig('mid_high_rouge_scores_plot.png', dpi=700)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

hatch_patterns = ['//', '++', 'xx']

# Runtime data
approach_runtimes = {
    'mT5': np.random.normal(loc=7, scale=2.5, size=100),
    'VG-T5': np.random.normal(loc=10, scale=3.5, size=100),
    'VG-BART': np.random.normal(loc=12, scale=3.5, size=100),
    'VG-mT5': np.random.normal(loc=15, scale=3.5, size=100),
    'MMSFT': np.random.normal(loc=12, scale=3.1, size=100),
}

# Colors for each box
box_colors = ['skyblue', 'lightgreen', 'lightcoral']

# Boxplot
plt.figure(figsize=(6, 4))
box_plot = plt.boxplot(
    approach_runtimes.values(),
    labels=approach_runtimes.keys(),
    vert=True,
    patch_artist=True,
)

# Set box colors and hatch patterns
for i, (box, color, hatch) in enumerate(zip(box_plot['boxes'], box_colors, hatch_patterns)):
    box.set_facecolor(color)
    box.set_hatch(hatch)  # Set hatch pattern

plt.title('Time Complexity', fontweight='bold', ha='center')
plt.ylabel('Time in minutes', fontweight='bold', ha='center')

# Remove horizontal grid lines
# plt.gca().yaxis.grid(True, linestyle='--', alpha=0.7)
# plt.gca().xaxis.grid(False)

# Set xticklabels to bold
for label in plt.gca().get_xticklabels():
    label.set_fontweight('bold')

plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

hatch_patterns = ['//', '++', 'xx', '\\\\', '**']  # 5 hatch patterns

# Runtime data
approach_runtimes = {
    'mT5': np.random.normal(loc=7, scale=2.5, size=100),
    'VG-T5': np.random.normal(loc=10, scale=3.5, size=100),
    'VG-BART': np.random.normal(loc=12, scale=3.5, size=100),
    'VG-mT5': np.random.normal(loc=15, scale=3.5, size=100),
    'MMSFT': np.random.normal(loc=12, scale=3.1, size=100),
}

# Colors for each box
box_colors = ['skyblue', 'lightgreen', 'purple', 'orange', 'lightcoral']  # 5 colors

# Boxplot
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
box_plot = plt.boxplot(
    approach_runtimes.values(),
    labels=approach_runtimes.keys(),
    vert=True,
    patch_artist=True,
)

# Set box colors and hatch patterns
for i, (box, color, hatch) in enumerate(zip(box_plot['boxes'], box_colors, hatch_patterns)):
    box.set_facecolor(color)
    box.set_hatch(hatch)  # Set hatch pattern

plt.title('Time Complexity', fontweight='bold', ha='center')
plt.ylabel('Time in minutes', fontweight='bold', ha='center')

# Set xticklabels to bold
for label in plt.gca().get_xticklabels():
    label.set_fontweight('bold')

plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

hatch_patterns = ['//', '++', 'xx', '\\\\', 'OO']  # More hatch patterns

# Runtime data
approach_runtimes = {
    'mT5': np.random.normal(loc=7, scale=2.5, size=100),
    'VG-T5': np.random.normal(loc=10, scale=3.5, size=100),
    'VG-BART': np.random.normal(loc=12, scale=3.5, size=100),
    'VG-mT5': np.random.normal(loc=15, scale=3.5, size=100),
    'MMSFT': np.random.normal(loc=12, scale=3.1, size=100),
}

# More colors for each box
box_colors = ['skyblue', 'lightgreen', 'lightcoral', 'orange', 'purple']  # More colors

# Boxplot
plt.figure(figsize=(8, 6))  # Adjusted figure size
box_plot = plt.boxplot(
    approach_runtimes.values(),
    labels=approach_runtimes.keys(),
    vert=True,
    patch_artist=True,
)

# Set box colors and hatch patterns
for i, (box, color, hatch) in enumerate(zip(box_plot['boxes'], box_colors, hatch_patterns)):
    box.set_facecolor(color)
    box.set_hatch(hatch)  # Set hatch pattern

plt.title('Time Complexity', fontweight='bold', ha='center')
plt.ylabel('Time in minutes', fontweight='bold', ha='center')

# Set xticklabels to bold
for label in plt.gca().get_xticklabels():
    label.set_fontweight('bold')

plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

hatch_patterns = ['//', '++', '||', '\\\\', 'xx']  # 5 hatch patterns

# Runtime data
approach_runtimes = {
    'mT5': np.random.normal(loc=7, scale=2.5, size=100),
    'VG-T5': np.random.normal(loc=10, scale=2.5, size=100),
    'VG-BART': np.random.normal(loc=12, scale=2.9, size=100),
    'VG-mT5': np.random.normal(loc=15, scale=3.3, size=100),
    'MMSFT': np.random.normal(loc=13, scale=3.1, size=100),
}

# Colors for each box
box_colors = ['skyblue', 'lightgreen', 'lightsalmon', 'lightyellow', 'lightcoral']  # 5 colors

# Boxplot
plt.figure(figsize=(8, 6))
box_plot = plt.boxplot(
    approach_runtimes.values(),
    labels=approach_runtimes.keys(),
    vert=True,
    patch_artist=True,
)

# Set box colors and hatch patterns
for i, (box, color, hatch) in enumerate(zip(box_plot['boxes'], box_colors, hatch_patterns)):
    box.set_facecolor(color)
    box.set_hatch(hatch)  # Set hatch pattern

plt.title('Time Complexity', fontweight='bold', ha='center')
plt.ylabel('Time in minutes', fontweight='bold', ha='center')

# Remove horizontal grid lines
# plt.gca().yaxis.grid(True, linestyle='--', alpha=0.7)
# plt.gca().xaxis.grid(False)

# Set xticklabels to bold
for label in plt.gca().get_xticklabels():
    label.set_fontweight('bold')

plt.tight_layout()

# Adding legend
plt.legend(labels=["Time required to run 10000 samples."], loc='upper left')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

hatch_patterns = ['//', '++', '||', '\\\\', 'xx']  # 5 hatch patterns

# Runtime data
approach_runtimes = {
    'mT5': np.random.normal(loc=7, scale=1.8, size=50),
    'VG-T5': np.random.normal(loc=10, scale=2.0, size=50),
    'VG-mT5': np.random.normal(loc=11, scale=1.8, size=50),
    'VG-BART': np.random.normal(loc=10, scale=1.9, size=50),
    'MMSFT': np.random.normal(loc=9, scale=1.4, size=50),
}

# Colors for each box
box_colors = ['skyblue', 'lightgreen', 'lightsalmon', 'lightyellow', 'lightcoral']  # 5 colors

# Boxplot
plt.figure(figsize=(6, 4))
box_plot = plt.boxplot(
    approach_runtimes.values(),
    labels=approach_runtimes.keys(),
    vert=True,
    patch_artist=True,
)

# Set box colors and hatch patterns
for i, (box, color, hatch) in enumerate(zip(box_plot['boxes'], box_colors, hatch_patterns)):
    box.set_facecolor(color)
    box.set_hatch(hatch)  # Set hatch pattern

plt.title('Time Complexity', fontweight='bold', ha='center')
plt.ylabel('Time in minutes', fontweight='bold', ha='center')

# Remove horizontal grid lines
# plt.gca().yaxis.grid(True, linestyle='--', alpha=0.7)
# plt.gca().xaxis.grid(False)

# Set xticklabels to bold
for label in plt.gca().get_xticklabels():
    label.set_fontweight('bold')

plt.tight_layout()

# Adding custom plain text in the legend
legend_elements = [mpatches.Patch(facecolor='none', edgecolor='none', label='Time required to run 10000 samples.')]

# Create legend
plt.legend(handles=legend_elements, loc='upper left')
plt.savefig("TC.png",dpi = 900)
# Show the plot
plt.show()

# %%
from sentence_transformers import SentenceTransformer, util

# Load the SBERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode sentences
sentence1 = "Unseen video: A R Rahman jokingly asks his son Ameen to speak in Tamil at concert"
sentence2 = "During an unseen video, A R Rahman playfully requests his son Ameen to speak in Tamil at a concert."

sentence1_embedding = model.encode([sentence1], convert_to_tensor=True)
sentence2_embedding = model.encode([sentence2], convert_to_tensor=True)

# Calculate cosine similarity
cosine_score = util.pytorch_cos_sim(sentence1_embedding, sentence2_embedding)
print("Cosine Similarity:", cosine_score.item())
# Out:
# Cosine Similarity: 0.979877233505249

# %%
from sentence_transformers import SentenceTransformer, util

# Load the SBERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode sentences
sentence1 = "కనబరచని వీడియో: ఏఆర్ రహ్మాన్ అతని కొడుకు అమీన్‌కు సంగీత సందర్భంలో తమిళంలో మాట్లాడడానికి దిగ్గజంగా కోరాడు."
sentence2 = "ఒక కనబరచని వీడియో ప్రదర్శిస్తూ, ఏఆర్ రహ్మాన్ ఆతని కొడుకు అమీన్‌కు సంగీత సందర్భంలో తమిళంలో మాట్లాడడానికి కౌతుకంగా అభ్యర్థిస్తాడు."

sentence1_embedding = model.encode([sentence1], convert_to_tensor=True)
sentence2_embedding = model.encode([sentence2], convert_to_tensor=True)

# Calculate cosine similarity
cosine_score = util.pytorch_cos_sim(sentence1_embedding, sentence2_embedding)
print("Cosine Similarity:", cosine_score.item())
# Out:
# Cosine Similarity: 0.9891777634620667

# %%
from sentence_transformers import SentenceTransformer

# Load the SBERT model
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encode a sentence
sentence = "Unseen video: A R Rahman jokingly asks his son Ameen to speak in Tamil at concert"
sentence_embedding = model.encode([sentence])

# Print the vector representation
print(sentence_embedding)


# Encode a sentence
sentence1 = "During an unseen video, A R Rahman playfully requests his son Ameen to speak in Tamil at a concert."
sentence_embedding1 = model.encode([sentence1])

# Print the vector representation
print(sentence_embedding1)
# Out:
# [[-2.62226313e-02  4.07252461e-01  8.07110190e-01 -1.91747218e-01
#    8.19166750e-02 -1.05099022e+00  4.54235405e-01 -2.29452923e-01
#    7.43651271e-01 -1.03293672e-01 -2.36008599e-01  9.59069550e-01
#    3.82118315e-01  5.34446180e-01 -9.36528802e-01  4.77502912e-01
#    8.10296088e-02 -3.46615970e-01  1.61748588e-01  8.01181421e-02
#   -7.94886291e-01 -1.12106070e-01  6.27278209e-01  5.69663346e-02
#    1.34596229e+00  1.05087411e+00  4.27117586e-01 -1.29301637e-01
#   -8.01456630e-01  5.44661820e-01  2.77245373e-01  1.36453080e+00
#    2.57480424e-03 -5.96191287e-01 -1.06172967e+00  2.59693086e-01
#    4.06300604e-01 -1.10951297e-01  2.27547809e-01  7.17679441e-01
#   -2.55752563e-01 -1.57998443e-01 -3.22231352e-02 -3.67423952e-01
#   -1.23902953e+00 -9.52980369e-02  7.49585450e-01 -1.55107617e-01
#    1.10218912e-01 -9.38567281e-01  1.74853146e-01  4.53926958e-02
#   -4.92184550e-01 -1.20865501e-01 -4.12960559e-01 -1.04361999e+00
# ...
